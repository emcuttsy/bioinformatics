# %%
from Bio import Entrez
import pandas as pd
Entrez.email = "ecutts@mit.edu"
Entrez.api_key = '057f36326473f362b4123bee57854f2c3208'

# %% [markdown]
# Lots of this drawn from https://stackoverflow.com/questions/16504238/attempting-to-obtain-taxonomic-information-from-biopython. Thanks to whoever asked this question 7 years ago.

# %%
def get_tax_id(species):
    """to get data from ncbi taxomomy, we need to have the taxid. we can
    get that by passing the species name to esearch, which will return
    the tax id"""
    species = species.replace(' ', "+").strip()
    search = Entrez.esearch(term = species, db = "taxonomy", retmode = "xml")
    record = Entrez.read(search)
    return record['IdList'][0]

def get_tax_data(taxid):
    """once we have the taxid, we can fetch the record"""
    search = Entrez.efetch(id = taxid, db = "taxonomy", retmode = "xml")
    return Entrez.read(search)

taxid = get_tax_id('Gramella forsetii KT0803')
data = get_tax_data(taxid)
lineage = {d['Rank']:d['ScientificName'] for d in \
           data[0]['LineageEx'] if d['Rank'] in ['phylum','class','family', 'order', 'genus', 'species']}

# %%
def get_tax_data_for_list(species_list, tax_levels=['phylum','class','family', 'order', 'genus', 'species']):
    taxid_list = []
    lineage_list = []

    for species in species_list:
        print(species)
        taxid = get_tax_id(species) # Apply your functions
        data = get_tax_data(taxid)
        lineage = {d['Rank']:d['ScientificName'] for d in \
                   data[0]['LineageEx'] if d['Rank'] in tax_levels}

        taxid_list.append(taxid) # Append the data to lists already initiated        
        lineage_list.append(lineage)

    for lineage in lineage_list: #fill with '' when no tax data given
        for tax_level in tax_levels:
            if tax_level not in lineage.keys():
                lineage[tax_level] = ''
    
    columns = dict.fromkeys(['Organism Name', 'taxid'] + tax_levels) # Make columns for DataFrame
    columns['Organism Name'] = species_list
    columns['taxid'] = taxid_list
    for tax_level in tax_levels:
        columns[tax_level] = [l[tax_level] for l in lineage_list]

    data_frame = pd.DataFrame(columns)
    
    return taxid_list, lineage_list, data_frame

# %%
df = pd.read_csv('Data/NCBI-bacteroidetes-reference-genomes.csv')
df.rename(columns={'#Organism Name': 'Organism Name'}, inplace=True)
df.replace(to_replace=' Chromosome', value='Chromosome', inplace = True) # error with space before chromosome category
taxid_list = []
df.head()
# Out:
#                          Organism Name  \
# 0  Porphyromonas gingivalis ATCC 33277
# 1             Gramella forsetii KT0803
# 2       Alistipes putredinis DSM 17216
# 3                Phocaeicola coprocola
# 4   Bacteroides intestinalis DSM 17393
#
#                                    Organism Groups      Strain     BioSample  \
# 0  Bacteria;FCB group;Bacteroidetes/Chlorobi group  ATCC 33277  SAMD00060922
# 1  Bacteria;FCB group;Bacteroidetes/Chlorobi group      KT0803  SAMEA2272667
# 2  Bacteria;FCB group;Bacteroidetes/Chlorobi group   DSM 17216  SAMN00000002
# 3  Bacteria;FCB group;Bacteroidetes/Chlorobi group      AF24-2  SAMN09734467
# 4  Bacteria;FCB group;Bacteroidetes/Chlorobi group   DSM 17393  SAMN00000015
#
#     BioProject         Assembly     Level  Size(Mb)   GC%  \
# 0   PRJDA19051  GCA_000010505.1  Complete   2.35489  48.4
# 1   PRJEA19061  GCA_000060345.1  Complete   3.79847  36.6
# 2   PRJNA19655  GCA_000154465.1  Scaffold   2.55068  53.3
# 3  PRJNA482748  GCA_003458565.1  Scaffold   3.55378  40.8
# 4   PRJNA20523  GCA_000172175.1    Contig   6.05260  42.8
#
#                            Replicons     WGS  Scaffolds   CDS  \
# 0  chromosome:NC_010729.1/AP009380.1     NaN          1  1891
# 1  chromosome:NC_008571.1/CU207366.1     NaN          1  3368
# 2                                NaN  ABFK02         12  2209
# 3                                NaN  QRUU01        166  2733
# 4                                NaN  ABJL02          8  4494
#
#            Release Date                                        GenBank FTP  \
# 0  2008-05-20T23:06:00Z  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 1  2006-11-06T00:00:00Z  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2  2007-09-11T00:00:00Z  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 3  2018-09-05T00:00:00Z  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/003...
# 4  2008-01-30T00:00:00Z  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
#
#                                           RefSeq FTP
# 0  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# 1  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# 2  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# 3  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003...
# 4  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...

# %%
genome_list = df['Organism Name'].tolist()
chunks = []
for i in range(len(genome_list)//50):
    chunks.append(genome_list[(i*50):(i+1)*50])
    if i == len(genome_list)//50 - 1:
        chunks.append(genome_list[(i+1)*50:len(genome_list)])

# %%
taxid_lists = []
lineage_lists = []
data_frames = []
import time

count = 0
for chunk in chunks:
    print('starting chunk ' + str(count))
    taxid_list, lineage_list, data_frame = get_tax_data_for_list(chunk)
    print('appending')
    taxid_lists.append(taxid_list)
    lineage_list.append(lineage_list)
    data_frames.append(data_frame)
    count += 1
    print('sleeping 3 sec')
    time.sleep(3)
# Out:
# starting chunk 0
# Porphyromonas gingivalis ATCC 33277
# Gramella forsetii KT0803
# Alistipes putredinis DSM 17216
# Phocaeicola coprocola
# Bacteroides intestinalis DSM 17393
# Bacteroides caccae
# Parabacteroides merdae
# Bacteroides uniformis
# Bacteroides stercoris ATCC 43183
# Microscilla marina ATCC 23134
# Polaribacter irgensii 23-P
# Parabacteroides distasonis
# Psychroflexus torquis ATCC 700755
# Croceibacter atlanticus HTCC2559
# Leeuwenhoekiella blandensis MED217
# Zobellia galactanivorans
# Salinibacter ruber DSM 13855
# Kordia algicida OT-1
# Prevotella ruminicola
# Robiginitalea biformata HTCC2501
# Dokdonia donghaensis DSW-1
# Bacteroides finegoldii CL09T03C10
# Bacteroides eggerthii
# Phocaeicola plebeius
# Phocaeicola dorei
# Alloprevotella tannerae ATCC 51259
# Porphyromonas uenonis DSM 23387 = JCM 13868
# Prevotella bivia DSM 20514
# Porphyromonas endodontalis
# Capnocytophaga gingivalis
# Phocaeicola coprophilus
# Capnocytophaga sputigena
# Parabacteroides johnsonii CL02T12C29
# Prevotella copri
# Bacteroides cellulosilyticus
# Prevotella bergensis DSM 17361
# Leadbetterella byssophila DSM 17132
# Prevotella buccae ATCC 33574
# Zunongwangia profunda SM-A87
# Bacteroides xylanisolvens
# Prevotella oris
# Prevotella veroralis DSM 19559 = JCM 6290
# Prevotella timonensis
# Prevotella buccalis DNF00985
# Prevotella amnii
# Bacteroides coprosuis DSM 18011
# Prevotella multisaccharivorax DSM 17128
# Cellulophaga algicola DSM 14237
# Bacteroides helcogenes P 36-108
# Capnocytophaga granulosa
# appending
# sleeping 3 sec
# starting chunk 1
# Paludibacter propionicigenes WB4
# Niastella koreensis GR20-10
# Prevotella oulorum F0390
# Prevotella nigrescens ATCC 33563
# Odoribacter splanchnicus
# Mucilaginibacter paludis DSM 18603
# Alistipes shahii
# Prevotella bryantii
# Fluviicola taffensis DSM 16823
# Bacteroides oleiciplenus YIT 12058
# Barnesiella intestinihominis YIT 11860
# Alistipes indistinctus YIT 12060
# Odoribacter laneus YIT 12061
# Dysgonomonas mossii DSM 22836
# Dysgonomonas gadei ATCC BAA-286
# Paraprevotella clara
# Paraprevotella xylaniphila YIT 11841
# Bacteroides clarus YIT 12056
# Bacteroides fluxus YIT 12057
# Prevotella denticola
# Pseudopedobacter saltans DSM 12145
# Prevotella histicola F0411
# Capnocytophaga canimorsus
# Prevotella marshii DSM 16973 = JCM 13450
# Weeksella virosa DSM 16922
# Prevotella disiens
# Prevotella oralis ATCC 33269
# Prevotella micans F0438
# Myroides odoratimimus CIP 101113
# Anaerophaga thermohalophila DSM 12881
# Muricauda ruestringensis DSM 13258
# Rhodothermus marinus DSM 4252
# Prevotella multiformis DSM 16608
# Prevotella salivae F0493
# Prevotella dentalis DSM 3688
# Dyadobacter fermentans DSM 18053
# Chitinophaga pinensis
# Flectobacillus major DSM 103
# Prevotella pallens
# Bacteroides nordii CL02T12C05
# Bacteroides salyersiae CL02T12C01
# Parabacteroides goldsteinii DSM 19448 = WAL 12034
# Prevotella maculosa OT 289
# Echinicola vietnamensis DSM 17526
# Mesoflavibacter zeaxanthinifaciens DSM 18436
# Owenweeksia hongkongensis DSM 17368
# Ochrovirga pacifica
# Bizionia argentinensis JUB59
# Cyclobacterium marinum DSM 745
# Bacteroides faecis MAJ27
# appending
# sleeping 3 sec
# starting chunk 2
# Ornithobacterium rhinotracheale ORT-UMN 88
# Solitalea canadensis DSM 3403
# Saprospira grandis str. Lewin
# Niabella soli DSM 19437
# Tannerella forsythia
# Polaribacter filamentus
# Hymenobacter roseosalivarius DSM 11622
# Alistipes finegoldii
# Pontibacter actiniarum
# Aequorivita sublithincola DSM 14238
# Aquiflexum balticum DSM 16537
# Gillisia limnaea DSM 15749
# Belliella baltica DSM 15883
# Saccharicrinis fermentans DSM 9555 = JCM 21142
# Bergeyella zoohelcum
# Porphyromonas catoniae F0037
# Bacteroides heparinolyticus
# Myroides odoratus
# Joostella marina DSM 19592
# Prevotella stercorea DSM 18206
# Prevotella pleuritidis F0068
# Flavobacterium frigoris PS1
# Aquimarina agarilytica ZC1
# Flavobacterium indicum GPTSA100-9 = DSM 17447
# Adhaeribacter aquaticus DSM 16391
# Prevotella baroniae F0067
# Aquimarina agarivorans
# Prevotella saccharolytica F0055
# Chitinophaga ginsengisegetis
# Rudanella lutea DSM 19387
# Alkaliflexus imshenetskii DSM 15055
# Prevotella oryzae DSM 17970
# Rikenella microfusus DSM 15922
# Bernardetia litoralis DSM 6794
# Barnesiella viscericola DSM 18177
# Lacinutrix algicola
# Myroides injenensis M09-0166
# Pedobacter agri PB92
# Salisaeta longa DSM 21114
# Flavobacterium lindanitolerans
# Imtechella halotolerans K1
# Marinilabilia salmonicolor
# Flavobacterium antarcticum DSM 19726
# Olivibacter sitiensis DSM 17696
# Capnocytophaga cynodegmi
# Indibacter alkaliphilus LW1
# Psychroflexus gondwanensis ACAM 44
# Nitritalea halalkaliphila LW7
# Bacteroides massiliensis B84634 = Timone 84634 = DSM 17679 = JCM 13223
# Butyricimonas synergistica DSM 23225
# appending
# sleeping 3 sec
# starting chunk 3
# Cytophaga aurantiaca DSM 3654
# Flexithrix dorotheae DSM 6795
# Lewinella cohaerens DSM 23179
# Flavilitoribacter nigricans DSM 23189 = NBRC 102662
# Porphyromonas somerae
# Prevotella nanceiensis DSM 19126 = JCM 15639
# Lewinella persica DSM 23188
# Echinicola pacifica DSM 19836
# Pontibacter roseus DSM 17521
# Prevotella paludivivens DSM 17968 = JCM 13650
# Porphyromonas bennonis DSM 23058 = JCM 16335
# Bacteroides propionicifaciens DSM 19291 = JCM 14649
# Spirosoma panaciterrae DSM 21099
# Segetibacter koreensis DSM 18137
# Spirosoma luteum DSM 19990
# Spirosoma spitsbergense DSM 19989
# Niabella aurantiaca DSM 17617
# Prevotella conceptionensis 9403948
# Pedobacter arcticus A12
# Parabacteroides gordonii MS-1 = DSM 23371
# Alistipes onderdonkii subsp. vulgaris
# Elizabethkingia meningoseptica
# Chryseobacterium indologenes
# Sphingobacterium faecium
# Flavihumibacter petaseus NBRC 106054
# Cecembia lonarensis LW9
# Chryseobacterium taeanense
# Bacteroides gallinarum DSM 18171 = JCM 13658
# Riemerella columbina DSM 16469
# Bacteroides barnesiae DSM 18169 = JCM 13652
# Bacteroides graminisolvens DSM 19988 = JCM 15093
# Fulvivirga imtechensis AK7
# Fibrella aestuarina BUZ 2
# Mariniradius saccharolyticus AK6
# Porphyromonas gulae
# Prevotella loescheii DSM 19665 = JCM 12249 = ATCC 15930
# Epilithonimonas tenax DSM 16811
# Flavobacterium rivuli WB 3.3-2 = DSM 21788
# Proteiniphilum acetatigenes DSM 18083
# Psychroflexus tropicus DSM 15496
# Nafulsella turpanensis ZLM-10
# Rhodonellum psychrophilum GCM71 = DSM 17998
# Chryseobacterium vrystaatense
# Chryseobacterium shigense
# Chryseobacterium joostei
# Chryseobacterium bovis DSM 19482
# Dyadobacter alkalitolerans DSM 23607
# Cesiribacter andamanensis AMV16
# Aequorivita capsosiphonis DSM 23843
# Algoriphagus marincola HL-49
# appending
# sleeping 3 sec
# starting chunk 4
# Algoriphagus mannitolivorans DSM 15301
# Algoriphagus terrigena DSM 22685
# Algoriphagus vanfongensis DSM 17529
# Arenibacter certesii DSM 19833
# Flavobacterium suncheonense GH29-5 = DSM 17707
# Eisenibacter elegans DSM 3317
# Hugenholtzia roseola DSM 9546
# Eudoraea adriatica DSM 19308
# Flavobacterium gelidilacus DSM 15343
# Flavobacterium soli DSM 19725
# Flavobacterium subsaxonicum WB 4.1-42 = DSM 21790
# Pedobacter oryzae DSM 19973
# Gelidibacter mesophilus DSM 14095
# Gramella portivictoriae DSM 23547
# Gramella echinicola DSM 19838
# Hymenobacter norwichensis DSM 15439
# Mesonia mobilis DSM 19841
# Runella zeae DSM 19591
# Salinimicrobium xinjiangense DSM 19287
# Alloprevotella rava F0323
# Dyadobacter beijingensis DSM 21582
# Hymenobacter aerophilus DSM 13606
# Salinimicrobium terrae DSM 17865
# Arenibacter latericius DSM 15913
# Arcticibacter svalbardensis MN12-7
# Pedobacter glucosidilyticus
# Prevotella corporis DSM 18810 = JCM 8529
# Aquimarina latercula DSM 2041
# Aquimarina muelleri DSM 19832
# Tenacibaculum ovolyticum DSM 18103
# Chryseobacterium daeguense DSM 19388
# Chryseobacterium gregarium DSM 19109
# Chryseobacterium palustre DSM 21579
# Psychroserpens burtonensis DSM 12212
# Flavobacterium daejeonense
# Flavobacterium denitrificans DSM 15936
# Flavobacterium filum DSM 17961
# Flavobacterium tegetincola DSM 22377
# Flavobacterium frigidarium DSM 17623
# Gaetbulibacter saemankumensis DSM 17032
# Croceitalea dokdonensis DOKDO 023
# Maribacter dokdonensis
# Polaribacter dokdonensis DSW-5
# Chryseobacterium koreense CCUG 49689
# Butyricimonas virosa
# Chryseobacterium caeni DSM 17710
# Dysgonomonas capnocytophagoides
# Prevotella albensis DSM 11370 = JCM 12258
# Runella limosa DSM 17973
# Sporocytophaga myxococcoides DSM 11118
# appending
# sleeping 3 sec
# starting chunk 5
# Thermonema rossianum DSM 10300
# Alistipes senegalensis
# Chryseobacterium oranimense
# Hallella seregens ATCC 51272
# Flavobacterium cauense R2A-7
# Flavobacterium enshiense DK69
# Winogradskyella psychrotolerans RS-3
# Flavobacterium saliperosum
# Cellulophaga baltica 18
# Cyclobacterium qasimii
# Coprobacter fastidiosus NSB1
# Prevotella brevis P6B11
# Capnocytophaga haemolytica
# Flavobacterium limnosediminis JC2902
# Thermophagus xiamenensis
# Porphyromonas crevioricanis
# Zhouia amylolytica AD3
# Arenitalea lutea
# Phocaeicola abscessus CCUG 55929
# Sphingobacterium paucimobilis HER1398
# Bacteroides neonati
# Algoriphagus machipongonensis
# Gillisia marina
# Galbibacter marinus
# Sediminibacterium salmoneum NBRC 103935
# Bacteroides reticulotermitis JCM 10512
# Olleya marilimosa CAM030
# Aquimarina megaterium
# Aquimarina macrocephali JAMB N27
# Dyadobacter tibetensis Y620-1
# Bacteroides timonensis
# Alistipes timonensis JC136
# Alistipes ihumii AP11
# Flavobacterium succinicans
# Bacteroides acidifaciens
# Prevotella falsenii DSM 22864 = JCM 15124
# Prevotella aurantiaca JCM 15754
# Prevotella dentasini JCM 15908
# Bacteroides rodentium JCM 16496
# Prevotella shahii DSM 15611 = JCM 12083
# Bacteroides paurosaccharolyticus JCM 15092
# Bacteroides stercorirosoris
# Porphyromonas cangingivalis
# Porphyromonas gingivicanis
# Prolixibacter bellariivorans
# Phocaeicola sartorii
# Maribacter antarcticus DSM 21422
# Crocinitomix catalasitica ATCC 23190
# Prevotella enoeca
# Bacteroides faecichinchillae
# appending
# sleeping 3 sec
# starting chunk 6
# Prevotella fusca JCM 17724
# Bacteroides cutis
# Metaprevotella massiliensis
# Flavivirga eckloniae
# Hanstruepera neustonica
# Chryseobacterium viscerum
# Chryseobacterium oncorhynchi
# Chryseobacterium lactis
# Chryseobacterium glaciei
# Chryseobacterium mucoviscidosis
# Arenibacter catalasegens
# Arenibacter hampyeongensis
# Salinibacter altiplanensis
# Flavobacterium croceum DSM 17960
# appending
# sleeping 3 sec
# starting chunk 15
# Chryseobacterium humi
# Parabacteroides chinchillae
# Sphingobacterium lactis
# Flavobacterium urumqiense
# Prevotella lascolaii
# Nonlabens xylanidelens
# Lewinella xylanilytica
# Flavobacterium cyanobacteriorum
# Aureitalea marina
# Bacteroides bouchesdurhonensis
# Flavipsychrobacter stenotrophus
# Aureicoccus marinus
# Nonlabens tegetincola
# Polaribacter butkevichii
# Polaribacter gangjinensis
# Polaribacter glomeratus
# Nonlabens arenilitoris
# Polaribacter porphyrae
# Apibacter adventoris
# Sphingobacterium gobiense
# Tenacibaculum todarodis
# Muricauda pacifica
# Spirosoma oryzae
# Arcticibacter pallidicorallinus
# Mongoliibacter ruber
# Aurantibacter aestuarii
# Mesoflavibacter sabulilitoris
# Prolixibacter denitrificans
# Taibaiella chishuiensis
# Dyadobacter jiangsuensis
# Chitinophaga niastensis
# Cecembia rubra
# Chitinophaga ginsengisoli
# Brumimicrobium mesophilum
# Flavobacterium aurantiibacter
# Mangrovibacterium marinum
# Mucilaginibacter yixingensis
# Pontibacter mucosus
# Gramella gaetbulicola
# Kordia periserrulae
# Flavobacterium alvei
# Siphonobacter curvatus
# Parabacteroides bouchesdurhonensis
# Elizabethkingia occulta
# Flavobacterium faecale
# Pontibacter virosus
# Porphyromonas loveana
# Prevotella colorans
# Balneicella halophila
# Arcicella aurantiaca
# appending
# sleeping 3 sec
# starting chunk 16
# Xanthomarina spongicola
# Maribacter polysiphoniae
# Mucilaginibacter oryzae
# Dyadobacter jejuensis
# Sediminitomix flava
# Hymenobacter nivis
# Gramella salexigens
# Salegentibacter sediminis
# Reichenbachiella versicolor
# Pedobacter yonginense
# Winogradskyella aurantia
# Dysgonomonas alginatilytica
# Pedobacter nutrimenti
# Winogradskyella epiphytica
# Pedobacter yulinensis
# Taibaiella soli
# Algoriphagus chordae
# Hydrotalea sandarakina
# Breznakibacter xylanolyticus
# Flavobacterium tistrianum
# Flavobacterium ginsenosidimutans
# Bacteroides ndongoniae
# Bacteroides ilei
# Bacteroides togonis
# Algoriphagus aquaeductus
# Mesonia algae
# Flavobacterium nitrogenifigens
# Arcticibacterium luteifluviistationis
# Chitinophaga skermanii
# Arenibacter echinorum
# Chitinophaga dinghuensis
# Olleya aquimaris
# Larkinella arboricola
# Flavobacterium aquaticum
# Algoriphagus yeomjeoni
# Echinicola strongylocentroti
# Blattabacterium clevelandi
# Flavobacterium lacus
# Flavobacterium aciduliphilum
# Aequorivita lipolytica
# Aequorivita antarctica
# Mucilaginibacter rubeus
# Mucilaginibacter kameinonensis
# Chryseobacterium lathyri
# Flavobacterium psychrolimnae
# Nubsella zeaxanthinifaciens
# Butyricimonas faecalis
# Edaphocola flava
# Muricauda olearia
# Brumimicrobium glaciale
# Flavobacterium tibetense
# Cecembia calidifontis
# Aquimarina brevivitae
# Ancylomarina subtilis
# Paramuribaculum intestinale
# Pseudobacter ginsenosidimutans
# Duncaniella muris
# Olivibacter jilunii
# Pedobacter kyonggii
# Aquirufa antheringensis
# Hyunsoonleella pacifica
# Sphingobacterium alimentarium
# Flavobacterium circumlabens
# Albibacterium bauzanense
# Acetobacteroides hydrogenigenes
# Pedobacter psychrotolerans
# Mariniflexile fucanivorans
# Natronoflexus pectinivorans
# Tenacibaculum skagerrakense
# Anseongella ginsenosidimutans
# Winogradskyella wandonensis
# Sediminibacterium goheungense
# Pedobacter duraquae
# Flavobacterium dankookense
# Pedobacter metabolipauper
# Algoriphagus boseongensis
# Zeaxanthinibacter enoshimensis
# Tenacibaculum caenipelagi
# Flavobacterium cheniae
# Sphingobacterium paludis
# Maribacter caenipelagi
# Maribacter spongiicola
# Myroides indicus
# Sphingobacterium yanglingense
# Gelidibacter sediminis
# Dinghuibacter silviterrae
# Meridianimaribacter flavus
# Chryseobacterium xixisoli
# Algibacter wandonensis
# Gramella jeungdoensis
# Mucilaginibacter phyllosphaerae
# Mucilaginibacter psychrotolerans
# appending
# sleeping 3 sec
# starting chunk 20
# Flavobacterium sediminis
# Flavobacterium foetidum
# Hymenobacter wooponensis
# Hymenobacter elongatus
# Hymenobacter aquaticus
# Bacteroides caecimuri
# Robertkochia marina
# Sphingobacterium alkalisoli
# Puteibacter caeruleilacunae
# Echinicola rosea
# Sphingobacterium daejeonense
# Hymenobacter jeollabukensis
# Maribacter flavus
# Maribacter aurantiacus
# Dyadobacter sediminis
# Dyadobacter luticola
# Spirosoma lacussanchae
# Pedobacter ureilyticus
# Algibacter aestuarii
# Antarcticibacterium flavum
# Flavobacterium jejuense
# Chryseobacterium aquifrigidense
# Pedobacter westerhofensis
# Solitalea koreensis
# Saccharicrinis carchari
# Chryseobacterium rhizoplanae
# Flavobacterium resistens
# Chitinophaga polysaccharea
# Changchengzhania lutea
# Flammeovirga kamogawensis
# Parabacteroides acidifaciens
# Flavobacterium daemonense
# Bacteroides koreensis
# Bacteroides kribbi
# Chryseobacterium echinoideorum
# Aquimarina algiphila
# Algibacter amylolyticus
# Lacibacter cauensis
# Chitinophaga japonensis
# Flavobacterium tiangeerense
# Mucilaginibacter frigoritolerans
# Flavisolibacter ginsenosidimutans
# Mucilaginibacter ginsenosidivorans
# Panacibacter ginsenosidivorans
# Arachidicoccus ginsenosidivorans
# Mucilaginibacter ginsenosidivorax
# Adhaeribacter aerolatus
# Segetibacter aerophilus
# Chitinophaga cymbidii
# Vicingus serpentipes
# appending
# sleeping 3 sec
# starting chunk 21
# Phaeodactylibacter luteus
# Chryseobacterium hagamense
# Filimonas endophytica
# Luteibaculum oceani
# Subsaximicrobium wynnwilliamsii
# Gelidibacter salicanalis
# Gillisia hiemivivida
# Seonamhaeicola algicola
# Rufibacter glacialis
# Seonamhaeicola marinus
# Bizionia algoritergicola
# Bizionia saleffrena
# Spongiivirga citrea
# Leptobacterium flavescens
# Muriicola jejuensis
# Spirosoma agri
# Cryomorpha ignava
# Cyclobacterium jeungdonense
# Pedobacter indicus
# Hymenobacter jejuensis
# Mucilaginibacter corticis
# Mucilaginibacter hurinus
# Dyadobacter luteus
# Fibrisoma montanum
# Fluviicola chungangensis
# Chryseobacterium phocaeense
# Flavobacterium nackdongense
# Gelidibacter japonicus
# Mangrovimonas xylaniphaga
# Prevotella pectinovora
# Dyadobacter bucti
# Flavobacterium psychrotolerans
# Chryseobacterium lacus
# Lacibacter luteus
# Flavobacterium caseinilyticum
# Flavobacterium sandaracinum
# Flavobacterium hiemivividum
# Algoriphagus aquimaris
# Niastella caeni
# appending
# sleeping 3 sec
# starting chunk 24
# Flavicella sediminum
# Gramella sabulilitoris
# Seonamhaeicola maritimus
# Thermonema lapsum
# Wenyingzhuangia heitensis
# Dyadobacter arcticus
# Flavobacterium collinsii
# Flavobacterium cerinum
# Labilibacter sediminis
# Pedobacter helvus
# Wenyingzhuangia aestuarii
# Saonia flava
# Lewinella antarctica
# Butyricimonas paravirosa
# Sphingobacterium kitahiroshimense
# Tamlana crocina
# Chitinophaga varians
# Flammeovirga aprica JL-4
# Flammeovirga yaeyamensis
# Pseudobizionia ponticola
# Empedobacter stercoris
# Flavobacterium bomensis
# Flavobacterium petrolei
# Cochleicola gelatinilyticus
# Sphingobacterium shayense
# Pedobacter boryungensis
# Capnocytophaga felis
# Winogradskyella eckloniae
# Winogradskyella litoriviva
# Winogradskyella undariae
# Sphingobacterium puteale
# Chryseobacterium aureum
# Ancylomarina salipaludis
# Duncaniella freteri
# Empedobacter tilapiae
# Aequorivita sinensis
# Aequorivita lutea
# Maribacter luteus
# Costertonia aggregata
# Macellibacteroides fermentans
# Lutibacter citreus
# Maribacter algicola
# Flavobacterium alkalisoli
# Chryseobacterium binzhouense
# Chryseobacterium candidae
# Cyclobacterium xiamenense
# Bacteroides ovatus
# Cytophaga hutchinsonii ATCC 33406
# Bacteroides thetaiotaomicron
# Bacteroides vulgatus ATCC 8482
# appending
# sleeping 3 sec
# starting chunk 25
# Flavobacterium psychrophilum
# Prevotella melaninogenica ATCC 25845
# Chryseobacterium gleum
# Sphingobacterium spiritivorum
# Marivirga tractuosa DSM 4126
# Phocaeicola salanitronis DSM 18170
# Riemerella anatipestifer ATCC 11845 = DSM 15868
# Haliscomenobacter hydrossis DSM 1100
# Runella slithyformis DSM 19594
# Cellulophaga lytica DSM 7489
# Capnocytophaga ochracea DSM 7271
# Porphyromonas asaccharolytica DSM 20707
# Pedobacter heparinus DSM 2366
# Flavobacterium branchiophilum FL-15
# Prevotella intermedia
# Nonlabens dokdonensis DSW-6
# Flavobacterium columnare
# Elizabethkingia anophelis R26
# Porphyromonas levii DSM 23370
# Porphyromonas macacae DSM 20710 = JCM 13914
# Fibrisoma limi BUZ 3
# Empedobacter brevis
# Sphingobacterium mizutaii
# Bacteroides pyogenes
# Tenacibaculum maritimum
# Terrimonas ferruginea DSM 30193
# Hymenobacter swuensis DY53
# Prevotella scopos JCM 17725
# Pedobacter antarcticus
# Zobellia uliginosa
# Flavobacterium aquatile LMG 4008 = ATCC 11947
# Nonlabens marinus S1-08
# Nonlabens spongiae
# Nonlabens agnitus
# Bacteroides zoogleoformans
# Sphingobacterium multivorum
# Hymenobacter oligotrophus
# Duncaniella dubosii
# Tenacibaculum finnmarkense genomovar ulcerans
# Bacteroides fragilis NCTC 9343
# Flavobacterium johnsoniae UW101
# appending
# sleeping 3 sec

# %%
# all_taxa = pd.concat(data_frames)
# all_taxa.to_csv('Data/NCBI-bacteroidetes-all.csv', index=False)
# ^ use above only when running the code in the box above

all_taxa = pd.read_csv('Data/NCBI-bacteroidetes-all.csv')
all_taxa.head()
# Out:
#                          Organism Name   taxid         phylum           class  \
# 0  Porphyromonas gingivalis ATCC 33277  431947  Bacteroidetes     Bacteroidia
# 1             Gramella forsetii KT0803  411154  Bacteroidetes  Flavobacteriia
# 2       Alistipes putredinis DSM 17216  445970  Bacteroidetes     Bacteroidia
# 3                Phocaeicola coprocola  310298  Bacteroidetes     Bacteroidia
# 4   Bacteroides intestinalis DSM 17393  471870  Bacteroidetes     Bacteroidia
#
#                family             order          genus  \
# 0  Porphyromonadaceae     Bacteroidales  Porphyromonas
# 1   Flavobacteriaceae  Flavobacteriales       Gramella
# 2       Rikenellaceae     Bacteroidales      Alistipes
# 3                 NaN     Bacteroidales    Phocaeicola
# 4      Bacteroidaceae     Bacteroidales    Bacteroides
#
#                     species
# 0  Porphyromonas gingivalis
# 1         Gramella forsetii
# 2      Alistipes putredinis
# 3                       NaN
# 4  Bacteroides intestinalis

# %% [markdown]
# I want to have somewhere in the range of 100-200 taxa on the tree. So let's see how each of the taxonomic levels breaks down. Deleted Blattabacterium sp. (Cryptocercus punctulatus) str. Cpu	because it caused error: "list index out of range" when I tried to retrieve its taxid.

# %%
tax_levels = all_taxa.columns.tolist()[2:]
tax_level_counts = dict.fromkeys(tax_levels, 0)

for tax_level in tax_levels:
    tax_level_counts[tax_level] = len(set(all_taxa[tax_level]))
    
print(tax_level_counts)
# Out:
# {'phylum': 1, 'class': 7, 'family': 50, 'order': 8, 'genus': 298, 'species': 271}

# %%
pure_genus_data_frames = []
for genus in set(all_taxa['genus']):
    pure_genus_data_frames.append(all_taxa[all_taxa['genus'] == genus])

# %%
genus_representatives = []
# begin filtering
for pure_genus_data_frame in pure_genus_data_frames:
    
    genus_representative = None
    
    if(len(pure_genus_data_frame)) == 1: # if there is only one representative, it is the genus representative
        genus_representative = pure_genus_data_frame['Organism Name'].tolist()[0]
    
    else: # screen by assembly level
        assembly_levels = {'Contig': [], 'Scaffold': [], 'Complete': [], 'Chromosome': []} # group organisms by assembly level
       
        for organism in pure_genus_data_frame['Organism Name']:
            assembly_level = df[df['Organism Name'] == organism]['Level'].tolist()[0]
            assembly_levels[assembly_level].append(organism)
            
        if len(assembly_levels['Complete']) >= 1: # if 1 or more complete
            if len(assembly_levels['Complete']) == 1: # if only 1 complete
                genus_representative = assembly_levels['Complete'][0] # make it the representative
            else:
                to_consider = assembly_levels['Complete'] # else consider only complete genomes in next step
        
        elif len(assembly_levels['Chromosome']) >= 1: # elif 1 or more chromosome
            if len(assembly_levels['Chromosome']) == 1: # if only 1 chromosme
                genus_representative = assembly_levels['Chromosome'][0]
            else:
                to_consider = assembly_levels['Chromosme'] # else consider only chromosome genomes in next step
        
        elif len(assembly_levels['Scaffold']) >= 1: # elif 1 or more scaffold
            if len(assembly_levels['Scaffold']) == 1: # if only 1 scaffold
                genus_representative = assembly_levels['Scaffold'][0] # make it the representative
            else:
                to_consider = assembly_levels['Scaffold'] # else consider only scaffold genomes in next step
        
        else: 
            to_consider = pure_genus_data_frame['Organism Name'].tolist() # else consider contig genomes
    
    
    if genus_representative != None: # if a genus representative was already found
        genus_representatives.append(genus_representative) # return it an move on
    
    else:
        tax_levels = pure_genus_data_frame.columns[2:]
        filled_tax_level_count = dict.fromkeys(range(len(tax_levels)+1))
        for key in filled_tax_level_count:
            filled_tax_level_count[key] = []
            
        for organism in to_consider:
            row = pure_genus_data_frame[pure_genus_data_frame['Organism Name'] == organism]
            
            count = 0 # count filled tax info columns
            for tax_level in row.columns[2:]:
                if row[tax_level].tolist()[0] != 'nan':
                    count += 1
            filled_tax_level_count[count].append(organism)
        
        for i in range(len(tax_levels)+1):
            key = len(tax_levels)-i
            if len(filled_tax_level_count[key]) >= 1:
                genus_representative = min(filled_tax_level_count[key], key=len)# if there's more than one option, take the one with the shortest name
        genus_representatives.append(genus_representative)

# %%
representatives_df = all_taxa[all_taxa['Organism Name'].isin(genus_representatives)]
assemblys = df[df['Organism Name'].isin(genus_representatives)]['Assembly']
levels = df[df['Organism Name'].isin(genus_representatives)]['Level']
representatives_df.insert(2, column='Refseq Assembly', value=assemblys)
representatives_df.insert(3, column='Level', value=levels)

# %%
representatives_df.to_csv('Data/NCBI-bacteroidetes-genus-representatives.csv', index=False)
representatives_df['taxid'].to_csv('Data/NCBI-bacteroidetes-genus-representatives-taxids.csv', header=False, index=False)
representatives_df.head()
# Out:
#                         Organism Name   taxid  Refseq Assembly       Level  \
# 9       Microscilla marina ATCC 23134  313606  GCA_000169175.1      Contig
# 11         Parabacteroides distasonis     823  GCA_012273055.1  Chromosome
# 12  Psychroflexus torquis ATCC 700755  313595  GCA_000153485.2    Complete
# 13   Croceibacter atlanticus HTCC2559  216432  GCA_000196315.1    Complete
# 15           Zobellia galactanivorans   63186  GCA_000973105.1    Complete
#
#            phylum           class             family             order  \
# 9   Bacteroidetes      Cytophagia    Microscillaceae      Cytophagales
# 11  Bacteroidetes     Bacteroidia     Tannerellaceae     Bacteroidales
# 12  Bacteroidetes  Flavobacteriia  Flavobacteriaceae  Flavobacteriales
# 13  Bacteroidetes  Flavobacteriia  Flavobacteriaceae  Flavobacteriales
# 15  Bacteroidetes  Flavobacteriia  Flavobacteriaceae  Flavobacteriales
#
#               genus                  species
# 9       Microscilla       Microscilla marina
# 11  Parabacteroides                      NaN
# 12    Psychroflexus    Psychroflexus torquis
# 13     Croceibacter  Croceibacter atlanticus
# 15         Zobellia                      NaN
